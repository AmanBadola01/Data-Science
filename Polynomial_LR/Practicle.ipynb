# %%
#Importing libraries
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Formimg data Set for the ALGORITHM

x = 6* np.random.rand(100,1)-3
y = 0.5 * x**2 + 1.5*x + 2 + np.random.randn(100,1)
#Qudratic Equation -> Ax^2 + Bx + C , Where A = 0.5, B = 1.5, C = 2

plt.scatter(x,y,color= "g")
plt.xlabel("X Dataset")
plt.ylabel("Y Dataset")
# Out:
# Text(0, 0.5, 'Y Dataset')

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
#Implementing Simple linear regression

from sklearn.linear_model import LinearRegression
regression_1 = LinearRegression()

# %%
regression_1.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test, regression_1.predict(x_test))
print(score)
# Out:
# 0.7544137661808774

# %%
# Visualising the Simple Linear Regression Model

plt.plot(x_train,regression_1.predict(x_train), color= "r")
plt.scatter(x_train, y_train)
plt.xlabel("X dataset")
plt.ylabel("Y Dataset")
# Out:
# Text(0, 0.5, 'Y Dataset')

# %%
#Applying polynomial regression
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree=2, include_bias=True)
x_train_poly = poly.fit_transform(x_train)
x_test_poly = poly.transform(x_test)

# %%
x_train_poly
# Out:
# array([[ 1.00000000e+00,  1.64807492e+00,  2.71615093e+00],
#        [ 1.00000000e+00, -1.01287548e+00,  1.02591674e+00],
#        [ 1.00000000e+00, -7.36921393e-01,  5.43053140e-01],
#        [ 1.00000000e+00, -2.35149298e+00,  5.52951923e+00],
#        [ 1.00000000e+00,  4.05209798e-01,  1.64194980e-01],
#        [ 1.00000000e+00, -2.09276551e+00,  4.37966750e+00],
#        [ 1.00000000e+00, -2.26276279e+00,  5.12009545e+00],
#        [ 1.00000000e+00,  1.93392183e-01,  3.74005366e-02],
#        [ 1.00000000e+00, -2.42131106e+00,  5.86274726e+00],
#        [ 1.00000000e+00, -1.51997641e-01,  2.31032829e-02],
#        [ 1.00000000e+00,  8.70939562e-01,  7.58535720e-01],
#        [ 1.00000000e+00, -2.54649965e+00,  6.48466046e+00],
#        [ 1.00000000e+00, -2.98532125e+00,  8.91214299e+00],
#        [ 1.00000000e+00, -2.00908430e+00,  4.03641971e+00],
#        [ 1.00000000e+00, -5.73339672e-01,  3.28718380e-01],
#        [ 1.00000000e+00, -1.67129936e+00,  2.79324157e+00],
#        [ 1.00000000e+00, -2.55820276e+00,  6.54440136e+00],
#        [ 1.00000000e+00,  1.63944373e+00,  2.68777576e+00],
#        [ 1.00000000e+00,  2.64766818e-01,  7.01014678e-02],
#        [ 1.00000000e+00, -2.78431376e+00,  7.75240312e+00],
#        [ 1.00000000e+00, -1.49689349e+00,  2.24069011e+00],
#        [ 1.00000000e+00,  2.75813076e+00,  7.60728528e+00],
#        [ 1.00000000e+00, -1.01738698e+00,  1.03507626e+00],
#        [ 1.00000000e+00,  1.59898295e+00,  2.55674647e+00],
#        [ 1.00000000e+00, -1.80220625e+00,  3.24794738e+00],
#        [ 1.00000000e+00, -2.85063642e+00,  8.12612800e+00],
#        [ 1.00000000e+00,  1.98337978e+00,  3.93379536e+00],
#        [ 1.00000000e+00, -1.82585707e+00,  3.33375405e+00],
#        [ 1.00000000e+00,  9.22977914e-01,  8.51888229e-01],
#        [ 1.00000000e+00, -2.61980208e+00,  6.86336292e+00],
#        [ 1.00000000e+00, -2.34742578e-01,  5.51040779e-02],
#        [ 1.00000000e+00,  5.82575318e-01,  3.39394001e-01],
#        [ 1.00000000e+00, -5.69018179e-01,  3.23781688e-01],
#        [ 1.00000000e+00, -2.82484287e+00,  7.97973725e+00],
#        [ 1.00000000e+00, -9.10698859e-01,  8.29372412e-01],
#        [ 1.00000000e+00,  1.55142422e+00,  2.40691710e+00],
#        [ 1.00000000e+00,  5.70826268e-01,  3.25842628e-01],
#        [ 1.00000000e+00,  2.81068237e+00,  7.89993538e+00],
#        [ 1.00000000e+00, -1.94295239e+00,  3.77506398e+00],
#        [ 1.00000000e+00, -3.11108160e-01,  9.67882871e-02],
#        [ 1.00000000e+00, -4.91780599e-01,  2.41848158e-01],
#        [ 1.00000000e+00,  1.24184479e+00,  1.54217848e+00],
#        [ 1.00000000e+00, -1.47500885e+00,  2.17565112e+00],
#        [ 1.00000000e+00,  7.72250359e-01,  5.96370617e-01],
#        [ 1.00000000e+00, -4.25015842e-01,  1.80638466e-01],
#        [ 1.00000000e+00,  8.46686319e-01,  7.16877723e-01],
#        [ 1.00000000e+00, -2.73404997e+00,  7.47502927e+00],
#        [ 1.00000000e+00,  1.98527202e+00,  3.94130498e+00],
#        [ 1.00000000e+00,  2.95518019e+00,  8.73308995e+00],
#        [ 1.00000000e+00, -2.35029271e+00,  5.52387580e+00],
#        [ 1.00000000e+00, -6.92443969e-01,  4.79478651e-01],
#        [ 1.00000000e+00, -1.21142143e+00,  1.46754189e+00],
#        [ 1.00000000e+00,  7.07074340e-01,  4.99954122e-01],
#        [ 1.00000000e+00, -2.12374238e+00,  4.51028171e+00],
#        [ 1.00000000e+00,  2.31358267e+00,  5.35266476e+00],
#        [ 1.00000000e+00,  3.59281247e-02,  1.29083014e-03],
#        [ 1.00000000e+00, -2.63936372e+00,  6.96624083e+00],
#        [ 1.00000000e+00, -1.71950138e+00,  2.95668499e+00],
#        [ 1.00000000e+00, -3.03597303e-01,  9.21713221e-02],
#        [ 1.00000000e+00, -2.34394778e+00,  5.49409120e+00],
#        [ 1.00000000e+00,  4.27822519e-01,  1.83032107e-01],
#        [ 1.00000000e+00,  3.85402832e-01,  1.48535343e-01],
#        [ 1.00000000e+00,  1.42830839e+00,  2.04006484e+00],
#        [ 1.00000000e+00, -2.66345411e+00,  7.09398778e+00],
#        [ 1.00000000e+00, -1.03233912e+00,  1.06572407e+00],
#        [ 1.00000000e+00,  2.84251711e+00,  8.07990349e+00],
#        [ 1.00000000e+00,  2.94058297e+00,  8.64702820e+00],
#        [ 1.00000000e+00,  1.47087907e+00,  2.16348523e+00],
#        [ 1.00000000e+00, -1.34658091e+00,  1.81328014e+00],
#        [ 1.00000000e+00,  6.94162696e-01,  4.81861848e-01],
#        [ 1.00000000e+00, -6.82671618e-01,  4.66040538e-01],
#        [ 1.00000000e+00, -2.93700701e+00,  8.62601018e+00],
#        [ 1.00000000e+00, -7.62214530e-01,  5.80970990e-01],
#        [ 1.00000000e+00, -4.91076538e-01,  2.41156166e-01],
#        [ 1.00000000e+00,  1.24405530e+00,  1.54767358e+00],
#        [ 1.00000000e+00, -1.06859696e+00,  1.14189947e+00],
#        [ 1.00000000e+00, -2.82377302e+00,  7.97369407e+00],
#        [ 1.00000000e+00, -8.54051159e-01,  7.29403382e-01],
#        [ 1.00000000e+00, -1.83250283e+00,  3.35806664e+00],
#        [ 1.00000000e+00, -7.83825639e-01,  6.14382632e-01]])

# %%
from sklearn.metrics import r2_score
regression = LinearRegression()
regression.fit(x_train_poly, y_train)
y_pred = regression.predict(x_test_poly)
score = r2_score(y_test, y_pred)
print(score)
# Out:
# 0.9174482264903739

# %%
# Best Fit Line
plt.scatter(x_train, regression.predict(x_train_poly))
plt.scatter(x_train, y_train)
